# %% [markdown]
# # Data Visualization And Pre-processing

# %%
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = p.read_csv("train.csv")

# %%
df=data.dropna()

# %%
df['places'] = df.AREA.map({'Karapakkam':'Karapakkam', 'Anna Nagar':'Anna_Nagar', 'Adyar':'Adyar', 'Velachery':'Velachery',
'Chrompet':'Chrompet', 'KK Nagar':'KK_Nagar', 'TNagar':'T_Nagar', 'T Nagar':'T_Nagar', 'Chrompt':'Chrompet',
'Chrmpet':'Chrompet', 'Karapakam':'Karapakkam','Ana Nagar':'Anna_Nagar', 'Chormpet':'Chrompet', 'Adyr':'Adyar', 'Velchery':'Velachery','Ann Nagar':'Anna_Nagar',
'KKNagar':'KK_Nagar'})

# %%
del df['AREA']

# %%
p.crosstab(df.places,df.BUILDTYPE)
# Out:
# BUILDTYPE   Comercial  Commercial  House  Other  Others
# places
# Adyar               0         244    262      5     258
# Anna_Nagar          0         249    274      1     253
# Chrompet            1         556    591      5     538
# KK_Nagar            1         320    347      2     320
# Karapakkam          2         429    484      9     435
# T_Nagar             0         176    154      1     164
# Velachery           0         333    321      2     319

# %%
df['SALES_PRICE'].hist(figsize=(7,6), color='blue', alpha=0.7)
plt.xlabel('SALES_PRICE')
plt.ylabel('Property Details')
plt.title('Sales price of distribution of property')
# Out:
# Text(0.5, 1.0, 'Sales price of distribution of property')

# %%
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)
PropByVar(df, 'N_ROOM')
# Out:
# 4    35.98
# 3    29.93
# 5    17.47
# 2    13.02
# 6     3.59
# Name: N_ROOM, dtype: float64

# %%
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)
PropByVar(df, 'places')
# Out:
# Chrompet      23.97
# Karapakkam    19.26
# KK_Nagar      14.03
# Velachery     13.82
# Anna_Nagar    11.01
# Adyar         10.90
# T_Nagar        7.02
# Name: places, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15,10))
s.heatmap(df.corr(), ax=ax, annot=True)

# %%
df.columns
# Out:
# Index(['PRT_ID', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE', 'places'],
#       dtype='object')

# %%
a = df["places"]
sq = df["INT_SQFT"]
bd = df["N_BEDROOM"]
bt = df["N_BATHROOM"]
r = df["N_ROOM"]
p = df["PARK_FACIL"]
sc = df["SALE_COND"]
sp = df["SALES_PRICE"]

# %%
plt.plot(r, sq, color='c')
plt.xlabel('No of Rooms')
plt.ylabel('No of SQFT')
plt.title('No of Rooms by each SQFT')
plt.show()

# %%
df.columns
# Out:
# Index(['PRT_ID', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRIC
#        2.76 , 4.125, 3.025, 3.205, 3.465, 3.895, 2.48 , 4.49 , 2.77 ,
#        2.24 , 2.86 , 3.235, 2.46 , 2.59 , 3.445, 2.45 , 2.25 , 4.435,
#        3.715, 2.735, 4.4  , 4.63 , 3.835, 3.305, 2.375, 4.69 , 4.155,
#        3.455, 4.23 , 2.655, 3.685, 3.625, 4.025, 2.885, 4.36 , 2.945,
#        2.855, 4.115, 2.09 , 3.795, 3.045, 3.645, 2.975, 3.775, 2.21 ,
#        4.85 , 2.795, 4.135, 4.78 , 2.635, 4.095, 2.625, 3.725, 2.835,
#        4.79 , 3.115, 4.87 , 2.245, 4.865, 4.495, 3.375, 2.43 , 4.395,
#        3.545, 4.585, 4.705, 4.83 , 4.195, 3.365, 2.06 , 3.995, 3.965,
#        3.635, 3.695, 4.405, 3.785, 3.515, 3.385, 4.515, 4.95 , 4.255,
#        4.72 , 4.65 , 4.045, 2.32 , 4.73 , 4.075, 3.145, 2.715, 3.565,
#        4.655, 2.525, 2.565, 2.31 , 4.165, 2.925, 2.41 , 4.085, 3.525,
#        3.015, 2.22 , 4.275, 3.905, 2.515, 3.955, 3.845, 4.345, 2.585,
#        4.75 , 3.335, 2.18 , 2.23 , 4.67 , 2.455, 4.455, 2.805, 3.345,
#        4.62 , 4.105, 3.405, 4.615, 4.185, 2.815, 4.45 , 4.97 , 4.415,
#        4.055, 2.645, 2.685, 4.315, 2.845, 4.82 , 4.225, 3.155, 4.205,
#        4.51 , 2.865, 2.765, 4.605, 3.065, 2.545, 3.265, 4.425, 2.56 ,
#        2.745, 4.065, 4.295, 2.   , 4.55 , 3.975, 3.675, 2.915, 2.2  ,
#        3.005, 2.385, 2.38 , 3.665, 2.535, 3.325, 3.925, 3.125, 4.335,
#        4.385, 2.27 , 4.93 , 3.805, 4.77 , 2.195, 4.175, 2.675, 4.695,
#        2.445, 4.265, 4.765, 2.335, 2.465, 4.81 , 2.905, 3.195, 3.245,
#        4.675, 4.94 ])

# %%
df['class'] = df.QS_OVERALL.map({4.33 :1, 3.765:1, 3.09 :1, 4.01 :1, 3.29 :1, 3.32 :1, 2.67 :0, 3.26 :1, 3.55 :1,
       3.16 :1, 3.83 :1, 2.89 :0, 2.26 :0, 3.19 :1, 3.66 :1, 3.57 :1, 4.3  :1, 3.35 :1,
       4.76 :1, 3.39 :1, 3.43 :1, 3.73 :1, 3.59 :1, 3.74 :1, 2.29 :0, 3.17 :1, 4.18 :1,
       2.755:0, 2.11 :0, 2.605:0, 4.58 :1, 4.2  :1, 3.27 :1, 4.19 :1, 2.98 :0, 3.12 :1,
       3.08 :1, 3.85 :1, 3.42 :1, 3.2  :1, 4.   :1, 3.34 :1, 2.825:0, 3.46 :1, 4.07 :1,
       3.68 :1, 2.95 :0, 3.505:1, 2.97 :0, 3.63 :1, 3.76 :1, 3.77 :1, 2.78 :0, 3.985:1,
       3.04 :1, 2.88 :0, 4.21 :1, 2.42 :0, 3.8  :1, 2.54 :0, 3.84 :1, 2.395:0, 3.14 :1,
       2.49 :0, 3.175:1, 2.84 :0, 4.17 :1, 3.13 :1, 3.98 :1, 3.36 :1, 3.735:1, 2.62 :0,
       3.555:1, 3.855:1, 2.44 :0, 2.64 :0, 3.095:1, 3.915:1, 2.5  :0, 2.345:0, 2.615:0,
       2.76 :0, 4.125:1, 3.025:1, 3.205:1, 3.465:1, 3.895:1, 2.48 :0, 4.49 :1, 2.77 :0,
       2.24 :0, 2.86 :0, 3.235:1, 2.46 :0, 2.59 :0, 3.445:1, 2.45 :0, 2.25 :0, 4.435:1,
       3.715:1, 2.735:0, 4.4  :1, 4.63 :1, 3.835:1, 3.305:1, 2.375:0, 4.69 :1, 4.155:1,
       3.455:1, 4.23 :1, 2.655:0, 3.685:1, 3.625:1, 4.025:1, 2.885:0, 4.36 :1, 2.945:0,
       2.855:0, 4.115:1, 2.09 :0, 3.795:1, 3.045:1, 3.645:1, 2.975:0, 3.775:1, 2.21 :0,
       4.85 :1, 2.795:0, 4.135:1, 4.78 :1, 2.635:0, 4.095:1, 2.625:0, 3.725:1, 2.835:0,
       4.79 :1, 3.115:1, 4.87 :1, 2.245:0, 4.865:1, 4.495:1, 3.375:1, 2.43 :0, 4.395:1,
       3.545:1, 4.585:1, 4.705:1, 4.83 :1, 4.195:1, 3.365:1, 2.06 :0, 3.995:1, 3.965:1,
       3.635:1, 3.695:1, 4.405:1, 3.785:1, 3.515:1, 3.385:1, 4.515:1, 4.95 :1, 4.255:1,
       4.72 :1, 4.65 :1, 4.045:1, 2.32 :0, 4.73 :1, 4.075:1, 3.145:1, 2.715:0, 3.565:1,
       4.655:1, 2.525:0, 2.565:0, 2.31 :0, 4.165:1, 2.925:0, 2.41 :0, 4.085:1, 3.525:1,
       3.015:1, 2.22 :0, 4.275:1, 3.905:1, 2.515:0, 3.955:1, 3.845:1, 4.345:1, 2.585:0,
       4.75 :1, 3.335:1, 2.18 :0, 2.23 :0, 4.67 :1, 2.455:0, 4.455:1, 2.805:0, 3.345:1,
       4.62 :1, 4.105:1, 3.405:1, 4.615:1, 4.185:1, 2.815:0, 4.45 :1, 4.97 :1, 4.415:1,
       4.055:1, 2.645:0, 2.685:0, 4.315:1, 2.845:0, 4.82 :1, 4.225:1, 3.155:1, 4.205:1,
       4.51 :1, 2.865:0, 2.765:0, 4.605:1, 3.065:1, 2.545:0, 3.265:1, 4.425:1, 2.56 :0,
       2.745:0, 4.065:1, 4.295:1, 2.   :0, 4.55 :1, 3.975:1, 3.675:1, 2.915:0, 2.2  :0,
       3.005:1, 2.385:0, 2.38 :0, 3.665:1, 2.535:0, 3.325:1, 3.925:1, 3.125:1, 4.335:1,
       4.385:1, 2.27 :0, 4.93 :1, 3.805:1, 4.77 :1, 2.195:0, 4.175:1, 2.675:0, 4.695:1,
       2.445:0, 4.265:1, 4.765:1, 2.335:0, 2.465:0, 4.81 :1, 2.905:0, 3.195:1, 3.245:1,
       4.675:1, 4.94 :1})

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['PRT_ID', 'places', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
       'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
       'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
       'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',]
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(int)

# %% [markdown]
# Spliting Train/Test:

# %%
X = df.drop(labels='class', axis=1)

y = df.loc[:,'class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)
print("Number of training dataset: ", len(X_train))
print("Number of test dataset: ", len(X_test))
print("Total number of dataset: ", len(X_train)+len(X_test))
# Out:
# Number of training dataset:  4939
# Number of test dataset:  2117
# Total number of dataset:  7056
